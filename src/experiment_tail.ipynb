# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

x = list(range(10, 1000 + 10, 10))
y = [xs ** 2 for xs in x]

figs, axs = plt.subplots(1, 2)
sns.regplot(x, y, ax=axs[1])
axs[1].set_xlabel("Yolo")
plt.show()

# %%
import stupid_tails as st
imort numpy as np

sims, ns = np.load("tails_datas/fourth_sim_tails.npy")
# Out:
# -----------------------------------------------------------------------
# Instruction_Unclear                   Traceback (most recent call last)
# <ipython-input-1-194279cce5d4> in <module>()
#       3 get_ipython().run_line_magic('autoreload', '2')
#       4
# ----> 5 m.main()
#
# ~/ReposGit/purdue-internship/src/stupid_tails.py in main()
#     194
#     195     else:
# --> 196         raise Instruction_Unclear
#     197
#     198
#
# Instruction_Unclear:
